# %%
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection as plt_circles

plt.rcParams['figure.dpi'] = 200
plt.rcParams['savefig.dpi'] = 200

# %%
class Particles():

    particle_list = list()
    
    L = 1.0
    V0 = 4.0
    dt = 0.5

    def __init__(self,r):
        Particles.particle_list.append(self)
        self.r = r
        self.A = np.pi*self.r**2
        self.s = self.A*4/np.pi
        
        x = np.random.uniform(0,1)*self.L
        y = np.random.uniform(0,1)*self.L
        self.X = np.array([x,y])

        theta = np.random.uniform(0,2*np.pi)
        Vx = Particles.V0*np.cos(theta)
        Vy = Particles.V0*np.sin(theta)
        self.V = np.array([Vx,Vy])
        

    def step(self):
        self.update_velocity()

    def update_velocity(self):        
        self.X += self.V*Particles.dt

    def check_colision(self):
        pass

    def check_wall(self):
        pass


    @classmethod
    def plot_particles(cls):
        fig, ax = plt.subplots()
        ax.set_box_aspect(1)
        ax.set_xlim([0,cls.L])
        ax.set_ylim([0,cls.L])
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        circles = list()
        x = list()
        y = list()
        for particle in cls.particle_list:
            x.append(particle.X[0])
            y.append(particle.X[1])
            circles.append(plt.Circle((particle.X[0],particle.X[1]), radius=particle.r, color='k'))
        c = plt_circles(circles)
        ax.add_collection(c)

# %%
N = 100
for i in range(N):
    Particles(r=0.01)

# %%
#Particles.plot_particles()

# %%
cls = Particles
fig, ax = plt.subplots()
ax.set_box_aspect(1)
ax.set_xlim([0,cls.L])
ax.set_ylim([0,cls.L])
ax.set_xlabel('x')
ax.set_ylabel('y')


circles = list()
x = list()
y = list()
for particle in cls.particle_list:
    x.append(particle.x)
    y.append(particle.y)
    circles.append(plt.Circle((particle.x,particle.y), radius=particle.r, color='k'))
c = plt_circles(circles)
ax.add_collection(c)
    
    


def update_plot(frame):
    for particle in cls.particle_list:
        particle.step()
    
    for i, particle in enumerate(cls.particle_list):
        circles[i].center = (particle.x, particle.y)

    ax.collections.clear()
    ax.add_collection(c)

frame_count = 100
interval = 100

animation = FuncAnimation(fig, update_plot, frames=frame_count, interval=interval)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="726">

# %%
p1 = Particles(r=0.1)

# %%
p1.step()
p1.x
# Out:
# 4.37078037443563

# %%
p1.Vx
# Out:
# 3.6072827946057378

# %%
import matplotlib.animation as animation
from matplotlib import style

ani = animation.FuncAnimation(fig, plot_ccc, interval=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.animation import FuncAnimation

# %matplotlib notebook

fig, ax = plt.subplots()

x = np.linspace(0, 10, 100)
y = np.sin(x)
line, = ax.plot(x, y)

def update_plot(frame):
    line.set_ydata(np.sin(x + frame / 10.0))
    fig.canvas.draw()

frame_count = 100
interval = 100

animation = FuncAnimation(fig, update_plot, frames=frame_count, interval=interval)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
